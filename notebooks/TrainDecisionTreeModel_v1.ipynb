# %%
import pandas as pd
import numpy as np
import utils
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_percentage_error,mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
import category_encoders
from sklearn.preprocessing import StandardScaler



warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading and Preprocessing Data

# %%
df = utils.load_data()
df = utils.log_transformation(df)
df = utils.break_datetime(df)
df = df[df['site_id'].isin([1, 6])]
df.head()
# Out:
#        building_id           timestamp  meter_reading  site_id primary_use  \
# 11199          105 2016-01-01 08:00:00        46.1071        1   Education
# 11200          106 2016-01-01 08:00:00         0.7492        1   Education
# 11201          107 2016-01-01 08:00:00       350.3670        1   Education
# 11202          108 2016-01-01 08:00:00       182.5310        1   Education
# 11203          109 2016-01-01 08:00:00       164.3510        1   Education
#
#        square_feet  year_built  floor_count  air_temperature  cloud_coverage  \
# 11199        50623         NaN          5.0              2.2             NaN
# 11200         5374         NaN          4.0              2.2             NaN
# 11201        97532      2005.0         10.0              2.2             NaN
# 11202        81580      1913.0          5.0              2.2             NaN
# 11203        56995      1953.0          6.0              2.2             NaN
#
#        ...  sea_level_pressure  wind_direction  wind_speed  log_meter_reading  \
# 11199  ...              1022.3            60.0         1.0           3.852424
# 11200  ...              1022.3            60.0         1.0           0.559159
# 11201  ...              1022.3            60.0         1.0           5.861831
# 11202  ...              1022.3            60.0         1.0           5.212384
# 11203  ...              1022.3            60.0         1.0           5.108070
#
#        log_square_feet  year  weekofyear  dayofweek  month  hour
# 11199        10.832181  2015          53          5      1     8
# 11200         8.589514  2015          53          5      1     8
# 11201        11.487946  2015          53          5      1     8
# 11202        11.309352  2015          53          5      1     8
# 11203        10.950736  2015          53          5      1     8
#
# [5 rows x 22 columns]

# %%
# Missing value Imputation for weather
df = utils.nan_weather_filler(df)

df.isnull().sum()
# Out:
# building_id                0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# year_built            134265
# floor_count           102684
# air_temperature            0
# cloud_coverage             0
# dew_temperature            0
# precip_depth_1_hr          0
# sea_level_pressure         0
# wind_direction             0
# wind_speed                 0
# log_meter_reading          0
# log_square_feet            0
# year                       0
# weekofyear                 0
# dayofweek                  0
# month                      0
# hour                       0
# dtype: int64

# %%
# Encoding
df = utils.label_encode(df,'primary_use')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/goksuuzunturk/Desktop/DI 502 Project/DI502_ElectricityPrediction/notebooks/TrainDecisionTreeModel.ipynb Hücre 5 line 2
#       <a href='vscode-notebook-cell:/Users/goksuuzunturk/Desktop/DI%20502%20Project/DI502_ElectricityPrediction/notebooks/TrainDecisionTreeModel.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Encoding
# ----> <a href='vscode-notebook-cell:/Users/goksuuzunturk/Desktop/DI%20502%20Project/DI502_ElectricityPrediction/notebooks/TrainDecisionTreeModel.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df = utils.apply_holidays(df)
#       <a href='vscode-notebook-cell:/Users/goksuuzunturk/Desktop/DI%20502%20Project/DI502_ElectricityPrediction/notebooks/TrainDecisionTreeModel.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df.head()
#
# NameError: name 'utils' is not defined

# %% [markdown]
# # Decision Tree Regressor

# %%
features = ['primary_use_encoded','log_square_feet','air_temperature','month','dayofweek','hour','month']
target = ['log_meter_reading']

# %% [markdown]
# ### Train - Test Split

# %%
df=df.sort_values(by='timestamp')
train, test= train_test_split(df, test_size=0.20, shuffle=False)

# %%
y_train = train[target]
y_test = test[target]
X_train = train[features]
X_test = test[features]

# %% [markdown]
# ### Quantitative Analysis

# %% [markdown]
# Primary Use

# %%
MSE_train = []
R2_train = []
MAPE_train = []
MAE_train = []

MSE_test = []
R2_test = []
MAPE_test = []
MAE_test = []

# %%
features = ['primary_use_encoded','hour','dayofweek','month']
DTR = DecisionTreeRegressor(max_depth=13)
DTR.fit(X_train[features],y_train)
y_pred_train = DTR.predict(X_train[features])
train_error_mse = mean_squared_error(y_train,y_pred_train)
train_error_r2 = r2_score(y_train,y_pred_train)
train_error_mape = mean_absolute_percentage_error(y_train,y_pred_train)
train_error_mae = mean_absolute_error(y_train,y_pred_train)

print("MSE for train set is: ",train_error_mse)

print("R2 for train set is: ",train_error_r2)

print("MAPE for train set is: ",train_error_mape)

print("MAE for train set is: ",train_error_mae)

y_pred_test = DTR.predict(X_test[features])
test_error_mse = mean_squared_error(y_test,y_pred_test)
test_error_r2 = r2_score(y_test,y_pred_test)
test_error_mape = mean_absolute_percentage_error(y_test,y_pred_test)
test_error_mae = mean_absolute_error(y_test,y_pred_test)

print("MSE for test set is: ",test_error_mse)

print("R2 for test set is: ",test_error_r2)

print("MAPE for test set is: ",test_error_mape)

print("MAE for test set is: ",test_error_mae)

MSE_train.append(train_error_mse)
R2_train.append(train_error_r2)
MAPE_train.append(train_error_mape)
MAE_train.append(train_error_mae)

MSE_test.append(test_error_mse)
R2_test.append(test_error_r2)
MAPE_test.append(test_error_mape)
MAE_test.append(test_error_mae)
# Out:
# MSE for train set is:  1.4095211601252566
# R2 for train set is:  0.13640682930802495
# MAPE for train set is:  2601035905527.8447
# MAE for train set is:  0.8801043086518684
# MSE for test set is:  1.1998941090370039
# R2 for test set is:  0.11834102716574035
# MAPE for test set is:  373859308738.96686
# MAE for test set is:  0.8280784323439626

# %% [markdown]
# Square Feet

# %%
features = ['log_square_feet','hour','dayofweek','month']
DTR = DecisionTreeRegressor(max_depth=13)
DTR.fit(X_train[features],y_train)
y_pred_train = DTR.predict(X_train[features])
train_error_mse = mean_squared_error(y_train,y_pred_train)
train_error_r2 = r2_score(y_train,y_pred_train)
train_error_mape = mean_absolute_percentage_error(y_train,y_pred_train)
train_error_mae = mean_absolute_error(y_train,y_pred_train)

print("MSE for train set is: ",train_error_mse)

print("R2 for train set is: ",train_error_r2)

print("MAPE for train set is: ",train_error_mape)

print("MAE for train set is: ",train_error_mae)

y_pred_test = DTR.predict(X_test[features])
test_error_mse = mean_squared_error(y_test,y_pred_test)
test_error_r2 = r2_score(y_test,y_pred_test)
test_error_mape = mean_absolute_percentage_error(y_test,y_pred_test)
test_error_mae = mean_absolute_error(y_test,y_pred_test)

print("MSE for test set is: ",test_error_mse)

print("R2 for test set is: ",test_error_r2)

print("MAPE for test set is: ",test_error_mape)

print("MAE for test set is: ",test_error_mae)

MSE_train.append(train_error_mse)
R2_train.append(train_error_r2)
MAPE_train.append(train_error_mape)
MAE_train.append(train_error_mae)

MSE_test.append(test_error_mse)
R2_test.append(test_error_r2)
MAPE_test.append(test_error_mape)
MAE_test.append(test_error_mae)
# Out:
# MSE for train set is:  0.05219361525403282
# R2 for train set is:  0.9680217289656711
# MAPE for train set is:  2492763982572.1484
# MAE for train set is:  0.11030258514602785
# MSE for test set is:  0.5017053255847946
# R2 for test set is:  0.6313566349820903
# MAPE for test set is:  436550496062.45184
# MAE for test set is:  0.27569651231328757

# %% [markdown]
# Air Temperature

# %%
features = ['air_temperature','hour','dayofweek','month']
DTR = DecisionTreeRegressor(max_depth=13)
DTR.fit(X_train[features],y_train)
y_pred_train = DTR.predict(X_train[features])
train_error_mse = mean_squared_error(y_train,y_pred_train)
train_error_r2 = r2_score(y_train,y_pred_train)
train_error_mape = mean_absolute_percentage_error(y_train,y_pred_train)
train_error_mae = mean_absolute_error(y_train,y_pred_train)

print("MSE for train set is: ",train_error_mse)

print("R2 for train set is: ",train_error_r2)

print("MAPE for train set is: ",train_error_mape)

print("MAE for train set is: ",train_error_mae)

y_pred_test = DTR.predict(X_test[features])
test_error_mse = mean_squared_error(y_test,y_pred_test)
test_error_r2 = r2_score(y_test,y_pred_test)
test_error_mape = mean_absolute_percentage_error(y_test,y_pred_test)
test_error_mae = mean_absolute_error(y_test,y_pred_test)

print("MSE for test set is: ",test_error_mse)

print("R2 for test set is: ",test_error_r2)

print("MAPE for test set is: ",test_error_mape)

print("MAE for test set is: ",test_error_mae)

MSE_train.append(train_error_mse)
R2_train.append(train_error_r2)
MAPE_train.append(train_error_mape)
MAE_train.append(train_error_mae)

MSE_test.append(test_error_mse)
R2_test.append(test_error_r2)
MAPE_test.append(test_error_mape)
MAE_test.append(test_error_mae)
# Out:
# MSE for train set is:  1.6167669609505153
# R2 for train set is:  0.009430333097511734
# MAPE for train set is:  2670648941664.7
# MAE for train set is:  0.989988409718753
# MSE for test set is:  1.3639473862561229
# R2 for test set is:  -0.0022021464307906413
# MAPE for test set is:  432322718614.3886
# MAE for test set is:  0.9186219887173778

# %% [markdown]
# Square Feet & Primary Use

# %%
features = ['log_square_feet','primary_use_encoded','hour','dayofweek','month']
DTR = DecisionTreeRegressor(max_depth=13)
DTR.fit(X_train[features],y_train)
y_pred_train = DTR.predict(X_train[features])
train_error_mse = mean_squared_error(y_train,y_pred_train)
train_error_r2 = r2_score(y_train,y_pred_train)
train_error_mape = mean_absolute_percentage_error(y_train,y_pred_train)
train_error_mae = mean_absolute_error(y_train,y_pred_train)

print("MSE for train set is: ",train_error_mse)

print("R2 for train set is: ",train_error_r2)

print("MAPE for train set is: ",train_error_mape)

print("MAE for train set is: ",train_error_mae)

y_pred_test = DTR.predict(X_test[features])
test_error_mse = mean_squared_error(y_test,y_pred_test)
test_error_r2 = r2_score(y_test,y_pred_test)
test_error_mape = mean_absolute_percentage_error(y_test,y_pred_test)
test_error_mae = mean_absolute_error(y_test,y_pred_test)

print("MSE for test set is: ",test_error_mse)

print("R2 for test set is: ",test_error_r2)

print("MAPE for test set is: ",test_error_mape)

print("MAE for test set is: ",test_error_mae)

MSE_train.append(train_error_mse)
R2_train.append(train_error_r2)
MAPE_train.append(train_error_mape)
MAE_train.append(train_error_mae)

MSE_test.append(test_error_mse)
R2_test.append(test_error_r2)
MAPE_test.append(test_error_mape)
MAE_test.append(test_error_mae)
# Out:
# MSE for train set is:  0.03721709380559551
# R2 for train set is:  0.9771976264331791
# MAPE for train set is:  2424890078774.8906
# MAE for train set is:  0.09286281978150726
# MSE for test set is:  0.4902055833468873
# R2 for test set is:  0.6398064230533637
# MAPE for test set is:  437271329931.2336
# MAE for test set is:  0.25817607170561574

# %% [markdown]
# Square Feet & Air Temperature

# %%
features = ['log_square_feet','air_temperature','hour','dayofweek','month']
DTR = DecisionTreeRegressor(max_depth=13)
DTR.fit(X_train[features],y_train)
y_pred_train = DTR.predict(X_train[features])
train_error_mse = mean_squared_error(y_train,y_pred_train)
train_error_r2 = r2_score(y_train,y_pred_train)
train_error_mape = mean_absolute_percentage_error(y_train,y_pred_train)
train_error_mae = mean_absolute_error(y_train,y_pred_train)

print("MSE for train set is: ",train_error_mse)

print("R2 for train set is: ",train_error_r2)

print("MAPE for train set is: ",train_error_mape)

print("MAE for train set is: ",train_error_mae)

y_pred_test = DTR.predict(X_test[features])
test_error_mse = mean_squared_error(y_test,y_pred_test)
test_error_r2 = r2_score(y_test,y_pred_test)
test_error_mape = mean_absolute_percentage_error(y_test,y_pred_test)
test_error_mae = mean_absolute_error(y_test,y_pred_test)

print("MSE for test set is: ",test_error_mse)

print("R2 for test set is: ",test_error_r2)

print("MAPE for test set is: ",test_error_mape)

print("MAE for test set is: ",test_error_mae)

MSE_train.append(train_error_mse)
R2_train.append(train_error_r2)
MAPE_train.append(train_error_mape)
MAE_train.append(train_error_mae)

MSE_test.append(test_error_mse)
R2_test.append(test_error_r2)
MAPE_test.append(test_error_mape)
MAE_test.append(test_error_mae)
# Out:
# MSE for train set is:  0.05048575650200518
# R2 for train set is:  0.9690681092517439
# MAPE for train set is:  1945151797737.1025
# MAE for train set is:  0.10576540261315917
# MSE for test set is:  0.49853289143442014
# R2 for test set is:  0.6336876782077698
# MAPE for test set is:  433413872061.00507
# MAE for test set is:  0.2749330304247608

# %% [markdown]
# All Features

# %%
features = ['air_temperature','log_square_feet','primary_use_encoded','hour','dayofweek','month']
DTR = DecisionTreeRegressor(max_depth=13)
DTR.fit(X_train[features],y_train)
y_pred_train = DTR.predict(X_train[features])
train_error_mse = mean_squared_error(y_train,y_pred_train)
train_error_r2 = r2_score(y_train,y_pred_train)
train_error_mape = mean_absolute_percentage_error(y_train,y_pred_train)
train_error_mae = mean_absolute_error(y_train,y_pred_train)

print("MSE for train set is: ",train_error_mse)

print("R2 for train set is: ",train_error_r2)

print("MAPE for train set is: ",train_error_mape)

print("MAE for train set is: ",train_error_mae)

y_pred_test = DTR.predict(X_test[features])
test_error_mse = mean_squared_error(y_test,y_pred_test)
test_error_r2 = r2_score(y_test,y_pred_test)
test_error_mape = mean_absolute_percentage_error(y_test,y_pred_test)
test_error_mae = mean_absolute_error(y_test,y_pred_test)

print("MSE for test set is: ",test_error_mse)

print("R2 for test set is: ",test_error_r2)

print("MAPE for test set is: ",test_error_mape)

print("MAE for test set is: ",test_error_mae)

MSE_train.append(train_error_mse)
R2_train.append(train_error_r2)
MAPE_train.append(train_error_mape)
MAE_train.append(train_error_mae)

MSE_test.append(test_error_mse)
R2_test.append(test_error_r2)
MAPE_test.append(test_error_mape)
MAE_test.append(test_error_mae)
# Out:
# MSE for train set is:  0.025884806192865668
# R2 for train set is:  0.9841407546866074
# MAPE for train set is:  1927241385999.683
# MAE for train set is:  0.08196870716343202
# MSE for test set is:  0.4837876478774565
# R2 for test set is:  0.644522197846388
# MAPE for test set is:  432388218037.81226
# MAE for test set is:  0.24943287765311875

# %%
# Plot results
plt.figure(figsize=(16, 10))

# MSE Plot
plt.subplot(2, 2, 1)
plt.plot(range(1, 7), MSE_train, marker='o', linestyle='-', color='blue', label='Train')
plt.plot(range(1, 7), MSE_test, marker='o', linestyle='-', color='orange', label='Test')
plt.xlabel('Groups')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Mean Squared Error (MSE) for Train and Test')
plt.legend()

# R2 Plot
plt.subplot(2, 2, 2)
plt.plot(range(1, 7), R2_train, marker='o', linestyle='-', color='green', label='Train')
plt.plot(range(1, 7), R2_test, marker='o', linestyle='-', color='red', label='Test')
plt.xlabel('Groups')
plt.ylabel('R-squared (R2)')
plt.title('R-squared (R2) for Train and Test')
plt.legend()

# MAPE Plot
plt.subplot(2, 2, 3)
plt.plot(range(1, 7), MAPE_train, marker='o', linestyle='-', color='purple', label='Train')
plt.plot(range(1, 7), MAPE_test, marker='o', linestyle='-', color='yellow', label='Test')
plt.xlabel('Groups')
plt.ylabel('Mean Absolute Percentage Error (MAPE)')
plt.title('Mean Absolute Percentage Error (MAPE) for Train and Test')
plt.legend()

# MAE Plot
plt.subplot(2, 2, 4)
plt.plot(range(1, 7), MAE_train, marker='o', linestyle='-', color='cyan', label='Train')
plt.plot(range(1, 7), MAE_test, marker='o', linestyle='-', color='brown', label='Test')
plt.xlabel('Groups')
plt.ylabel('Mean Absolute Error (MAE)')
plt.title('Mean Absolute Error (MAE) for Train and Test')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Save the model

# %%
utils.save_model(DTR,"DTR_v1")

# %% [markdown]
# Reuse the model by loading

# %%
DTR = utils.load_model("DTR_v1")

DTR
# Out:
# DecisionTreeRegressor(max_depth=13)
